# %%
import pandas as pd
import matplotlib.pyplot as plt 

data_path = "../data/processed/cleaned_products.csv"
df = pd.read_csv(data_path)


print("Basic Statistics")
print(df.describe())

plt.hist(df["price"], bins=20, edgecolor="black")
plt.title("Distribución de precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()


print("Primeros 5 productos con mayor precio:")
highestPrices=df.nlargest(5,"price")
print(highestPrices)
# Out:
# Basic Statistics
#           price
# count    5.0000
# mean   663.7900
# std    350.3601
# min    118.9900
# 25%    499.9900
# 50%    899.9900
# 75%    899.9900
# max    899.9900
# Primeros 5 productos con mayor precio:
#          title      description   price
# 0       Iphone            White  899.99
# 1       Iphone           Silver  899.99
# 2       Iphone            Black  899.99
# 3  Ubuntu Edge   Sapphire glass  499.99
# 4  Sony Xperia  GPS, waterproof  118.99
